# %% [markdown]
# It is a notebook to coustomise spacy and check how is spacy predicting symptoms

# %%
import spacy

# %%
symptom_finder=spacy.load(name='en_core_web_sm')
# Out:
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.1.0) was trained with spaCy v3.1.0 and may not be 100% compatible with the current version (3.6.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
import joblib
symp=joblib.load('symp.joblib')
symptom_pattern=joblib.load('symptom_pattern.joblib')

# %%
symptom_pattern
# Out:
# [{'label': 'SYMPTOM', 'pattern': [{'Lower': 'itch'}]},
#  {'label': 'SYMPTOM', 'pattern': [{'Lower': 'skin'}, {'Lower': 'rash'}]},
#  {'label': 'SYMPTOM',
#   'pattern': [{'Lower': 'nodal'}, {'Lower': 'skin'}, {'Lower': 'eruption'}]},
#  {'label': 'SYMPTOM',
#   'pattern': [{'Lower': 'continuous'}, {'Lower': 'sneeze'}]},
#  {'label': 'SYMPTOM', 'pattern': [{'Lower': 'shiver'}]},
#  {'label': 'SYMPTOM', 'pattern': [{'Lower': 'chill'}]},
#  {'label': 'SYMPTOM', 'pattern': [{'Lower': 'joint'}, {'Lower': 'pain'}]},
#  {'label': 'SYMPTOM', 'pattern': [{'Lower': 'stomach'}, {'Lower': 'pain'}]},
#  {'label': 'SYMPTOM', 'pattern': [{'Lower': 'acidity'}]},
#  {'label': 'SYMPTOM',
#   'pattern': [{'Lower': 'ulcer'}, {'Lower': 'on'}, {'Lower': 'tongue'}]},
#  {'label': 'SYMPTOM', 'pattern': [{'Lower': 'muscle'}, {'Lower': 'waste'}]},
#  {'label': 'SYMPTOM', 'pattern': [{'Lower': 'vomit'}]},
#  {'label': 'SYMPTOM',
#   'pattern': [{'Lower': 'burn'}, {'Lower': 'micturition'}]},
# ...

# %% [markdown]
# customizing spacy

# %%
# r=symptom_finder.add_pipe('entity_ruler')
# r.add_patterns(symptom_pattern)
# Out:
# itch

# %%
joblib.dump(symptom_finder,'symptom_finder.joblib')
# Out:
# ['symptom_finder.joblib']
